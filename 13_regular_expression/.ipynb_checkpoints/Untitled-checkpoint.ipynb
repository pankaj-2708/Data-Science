# %%
import re

# %% [markdown]
# ## functions in re
# 1. re.findall()<br>
# Returns all non-overlapping matches of a pattern in the string as a list. It scans the string from left to right.<br><br>
# 2. re.compile()<br>
# Compiles a regex into a pattern object, which can be reused for matching or substitutions.<br><br>
# 3. re.split() <br>
# Splits a string wherever the pattern matches. The remaining characters are returned as list elements.<br><br>

# %%
string = """Hello my Number is 123456789 and
            my friend's number is 987654321"""

# findall - for finding all sequences of one or more digits in the given string.
pattern='\d+'
print(re.findall(pattern,string))

# compile -  for searching pattern [a-e] matches all lowercase letters between 'a' and 'e'
pattern=re.compile('[a-e]')
pattern.findall(string)

# split 
print(re.split('\W+', 'Words, words , Words'))
print(re.split('\W+', "Word's words Words"))
print(re.split('\W+', 'On 12th Jan 2016, at 11:02 AM'))
print(re.split('\d+', 'On 12th Jan 2016, at 11:02 AM'))
# Out:
# ['123456789', '987654321']
# ['Words', 'words', 'Words']
# ['Word', 's', 'words', 'Words']
# ['On', '12th', 'Jan', '2016', 'at', '11', '02', 'AM']
# ['On ', 'th Jan ', ', at ', ':', ' AM']
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\W'
# <>:14: SyntaxWarning: invalid escape sequence '\W'
# <>:15: SyntaxWarning: invalid escape sequence '\W'
# <>:16: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\W'
# <>:14: SyntaxWarning: invalid escape sequence '\W'
# <>:15: SyntaxWarning: invalid escape sequence '\W'
# <>:16: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\panka\AppData\Local\Temp\ipykernel_43472\870316406.py:5: SyntaxWarning: invalid escape sequence '\d'
#   pattern='\d+'
# C:\Users\panka\AppData\Local\Temp\ipykernel_43472\870316406.py:13: SyntaxWarning: invalid escape sequence '\W'
#   print(re.split('\W+', 'Words, words , Words'))
# C:\Users\panka\AppData\Local\Temp\ipykernel_43472\870316406.py:14: SyntaxWarning: invalid escape sequence '\W'
#   print(re.split('\W+', "Word's words Words"))
# C:\Users\panka\AppData\Local\Temp\ipykernel_43472\870316406.py:15: SyntaxWarning: invalid escape sequence '\W'
#   print(re.split('\W+', 'On 12th Jan 2016, at 11:02 AM'))
# C:\Users\panka\AppData\Local\Temp\ipykernel_43472\870316406.py:16: SyntaxWarning: invalid escape sequence '\d'
#   print(re.split('\d+', 'On 12th Jan 2016, at 11:02 AM'))
